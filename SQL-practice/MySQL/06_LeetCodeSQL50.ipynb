# %% [markdown]
# Its in LeetCode itself, with commands and comments of how to solve.

# %%
# %load_ext sql
# %run ../setup.py
# %sql engine

# %%
# %%sql
# #Q. 1683 - To find the length of 'strings' in a coloumn
# SELECT tweet_id FROM Tweets WHERE LENGTH(content)>15;
